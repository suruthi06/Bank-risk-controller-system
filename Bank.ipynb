# %%
import pandas as pd
from sklearn.metrics import mutual_info_score
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import scipy.stats as stats
from scipy.stats import pearsonr
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("loan_data.csv")
df.head(5)
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE_x CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1           Cash loans           M            N
# 1      100003       0           Cash loans           F            N
# 2      100003       0           Cash loans           F            N
# 3      100003       0           Cash loans           F            N
# 4      100004       0      Revolving loans           M            Y
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  \
# 0               Y             0          202500.0      406597.5
# 1               N             0          270000.0     1293502.5
# 2               N             0          270000.0     1293502.5
# 3               N             0          270000.0     1293502.5
# 4               Y             0           67500.0      135000.0
#
#    AMT_ANNUITY_x  ...  NAME_SELLER_INDUSTRY CNT_PAYMENT NAME_YIELD_GROUP  \
# 0        24700.5  ...       Auto technology        24.0       low_normal
# 1        35698.5  ...                   XNA        12.0       low_normal
# 2        35698.5  ...             Furniture         6.0           middle
# 3        35698.5  ...  Consumer electronics        12.0           middle
# 4         6750.0  ...          Connectivity         4.0           middle
#
#            PRODUCT_COMBINATION DAYS_FIRST_DRAWING DAYS_FIRST_DUE  \
# 0      POS other with interest           365243.0         -565.0
# 1             Cash X-Sell: low           365243.0         -716.0
# 2   POS industry with interest           365243.0         -797.0
# 3  POS household with interest           365243.0        -2310.0
# 4  POS mobile without interest           365243.0         -784.0
#
#    DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  \
# 0                      125.0          -25.0             -17.0
# 1                     -386.0         -536.0            -527.0
# 2                     -647.0         -647.0            -639.0
# 3                    -1980.0        -1980.0           -1976.0
# 4                     -694.0         -724.0            -714.0
#
#    NFLAG_INSURED_ON_APPROVAL
# 0                        0.0
# 1                        1.0
# 2                        0.0
# 3                        1.0
# 4                        0.0
#
# [5 rows x 158 columns]

# %%
# Separate categorical and numerical columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

# %%
df.shape
# Out:
# (1413701, 158)

# %%
df.dropna(subset=["OCCUPATION_TYPE"], inplace=True)  # drop null columns

# %%
categorical_columns = df[['NAME_CONTRACT_TYPE_x', 'CODE_GENDER', 'FLAG_OWN_CAR',
       'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE_x', 'NAME_INCOME_TYPE',
       'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
       'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START_x', 'ORGANIZATION_TYPE',
       'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE',
       'EMERGENCYSTATE_MODE', 'NAME_CONTRACT_TYPE_y',
       'WEEKDAY_APPR_PROCESS_START_y', 'FLAG_LAST_APPL_PER_CONTRACT',
       'NAME_CASH_LOAN_PURPOSE', 'NAME_CONTRACT_STATUS', 'NAME_PAYMENT_TYPE',
       'CODE_REJECT_REASON', 'NAME_TYPE_SUITE_y', 'NAME_CLIENT_TYPE',
       'NAME_GOODS_CATEGORY', 'NAME_PORTFOLIO', 'NAME_PRODUCT_TYPE',
       'CHANNEL_TYPE', 'NAME_SELLER_INDUSTRY', 'NAME_YIELD_GROUP',
       'PRODUCT_COMBINATION']]

# %%
for i in categorical_columns:
    df[i] = df[i].fillna(df[i].mode()[0])

# %%
# Check for null values in categorical columns
categorical_nulls = df[categorical_cols].isnull().sum()
print("Categorical Null Values:")
print(categorical_nulls)
# Out:
# Categorical Null Values:
# NAME_CONTRACT_TYPE_x            0
# CODE_GENDER                     0
# FLAG_OWN_CAR                    0
# FLAG_OWN_REALTY                 0
# NAME_TYPE_SUITE_x               0
# NAME_INCOME_TYPE                0
# NAME_EDUCATION_TYPE             0
# NAME_FAMILY_STATUS              0
# NAME_HOUSING_TYPE               0
# OCCUPATION_TYPE                 0
# WEEKDAY_APPR_PROCESS_START_x    0
# ORGANIZATION_TYPE               0
# FONDKAPREMONT_MODE              0
# HOUSETYPE_MODE                  0
# WALLSMATERIAL_MODE              0
# EMERGENCYSTATE_MODE             0
# NAME_CONTRACT_TYPE_y            0
# WEEKDAY_APPR_PROCESS_START_y    0
# FLAG_LAST_APPL_PER_CONTRACT     0
# NAME_CASH_LOAN_PURPOSE          0
# NAME_CONTRACT_STATUS            0
# NAME_PAYMENT_TYPE               0
# CODE_REJECT_REASON              0
# NAME_TYPE_SUITE_y               0
# NAME_CLIENT_TYPE                0
# NAME_GOODS_CATEGORY             0
# NAME_PORTFOLIO                  0
# NAME_PRODUCT_TYPE               0
# CHANNEL_TYPE                    0
# NAME_SELLER_INDUSTRY            0
# NAME_YIELD_GROUP                0
# PRODUCT_COMBINATION             0
# dtype: int64

# %%
# Calculate Mutual Information for categorical features
mi_scores = []
for feature in categorical_cols:
    mi = mutual_info_score(df[feature], df['TARGET'])
    mi_scores.append(mi)

# %%
hybrid_scores = [0.5 * mi for mi in mi_scores]

# %%
# Rank categorical features by mutual information scores
ranked_categorical_features = [feature for _, feature in sorted(zip(mi_scores, categorical_cols), reverse=True)]

# %%
# Select top N features
N = 10
selected_features = ranked_categorical_features[:N]

print("Selected Features:", selected_features)
# Out:
# Selected Features: ['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE', 'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS', 'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER', 'NAME_GOODS_CATEGORY']

# %%
df_1= df[['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE', 'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS', 'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER', 'NAME_GOODS_CATEGORY']]

# %%
df_1.head(5)
# Out:
#   OCCUPATION_TYPE            NAME_EDUCATION_TYPE       ORGANIZATION_TYPE  \
# 0        Laborers  Secondary / secondary special  Business Entity Type 3
# 1      Core staff               Higher education                  School
# 2      Core staff               Higher education                  School
# 3      Core staff               Higher education                  School
# 4        Laborers  Secondary / secondary special              Government
#
#            PRODUCT_COMBINATION CODE_REJECT_REASON NAME_CONTRACT_STATUS  \
# 0      POS other with interest                XAP             Approved
# 1             Cash X-Sell: low                XAP             Approved
# 2   POS industry with interest                XAP             Approved
# 3  POS household with interest                XAP             Approved
# 4  POS mobile without interest                XAP             Approved
#
#   NAME_INCOME_TYPE NAME_YIELD_GROUP CODE_GENDER   NAME_GOODS_CATEGORY
# 0          Working       low_normal           M              Vehicles
# 1    State servant       low_normal           F                   XNA
# 2    State servant           middle           F             Furniture
# 3    State servant           middle           F  Consumer Electronics
# 4          Working           middle           M                Mobile

# %%
df['NAME_YIELD_GROUP'].unique()
# Out:
# array(['low_normal', 'middle', 'XNA', 'high', 'low_action'], dtype=object)

# %%
selected_cat = df_1[['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE', 'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS', 'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER', 'NAME_GOODS_CATEGORY']]

# %%
nominal_variable = selected_cat[['OCCUPATION_TYPE','ORGANIZATION_TYPE','PRODUCT_COMBINATION','CODE_REJECT_REASON','NAME_GOODS_CATEGORY','CODE_GENDER']]

# %%
ordinal_variable = selected_cat[['NAME_EDUCATION_TYPE','NAME_CONTRACT_STATUS','NAME_INCOME_TYPE','NAME_YIELD_GROUP']]

# %%
from sklearn.preprocessing import LabelEncoder
def label_encoder(datafarme,column):
  le = LabelEncoder()
  for feature in column:
    datafarme[feature] = le.fit_transform(df[feature])
  return datafarme

# %%
label_encoder(df_1,nominal_variable)
# Out:
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\571510498.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\571510498.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\571510498.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\571510498.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\571510498.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\571510498.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
#          OCCUPATION_TYPE            NAME_EDUCATION_TYPE  ORGANIZATION_TYPE  \
# 0                      8  Secondary / secondary special                  5
# 1                      3               Higher education                 39
# 2                      3               Higher education                 39
# 3                      3               Higher education                 39
# 4                      8  Secondary / secondary special                 11
# ...                  ...                            ...                ...
# 1413696                8               Higher education                  5
# 1413697                8               Higher education                  5
# 1413698                8               Higher education                  5
# 1413699                8               Higher education                  5
# 1413700                8               Higher education                  5
#
#          PRODUCT_COMBINATION  CODE_REJECT_REASON NAME_CONTRACT_STATUS  \
# 0                         15                   7             Approved
# 1                          7                   7             Approved
# 2                         11                   7             Approved
# 3                          9                   7             Approved
# 4                         14                   7             Approved
# ...                      ...                 ...                  ...
# 1413696                    8                   7             Approved
# 1413697                    0                   1              Refused
# 1413698                    4                   1              Refused
# 1413699                    7                   7             Approved
# 1413700                   13                   7             Approved
#
#              NAME_INCOME_TYPE NAME_YIELD_GROUP  CODE_GENDER  \
# 0                     Working       low_normal            1
# 1               State servant       low_normal            0
# 2               State servant           middle            0
# 3               State servant           middle            0
# 4                     Working           middle            1
# ...                       ...              ...          ...
# 1413696  Commercial associate           middle            0
# 1413697  Commercial associate              XNA            0
# 1413698  Commercial associate       low_normal            0
# 1413699  Commercial associate       low_normal            0
# 1413700  Commercial associate             high            0
#
#          NAME_GOODS_CATEGORY
# 0                         24
# 1                         26
# 2                         11
# 3                          7
# 4                         18
# ...                      ...
# 1413696                   26
# 1413697                   26
# 1413698                   26
# 1413699                   26
# 1413700                    5
#
# [956121 rows x 10 columns]

# %%
label_encoder(df_1,ordinal_variable)
# Out:
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\571510498.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\571510498.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\571510498.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\571510498.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datafarme[feature] = le.fit_transform(df[feature])
#          OCCUPATION_TYPE  NAME_EDUCATION_TYPE  ORGANIZATION_TYPE  \
# 0                      8                    4                  5
# 1                      3                    1                 39
# 2                      3                    1                 39
# 3                      3                    1                 39
# 4                      8                    4                 11
# ...                  ...                  ...                ...
# 1413696                8                    1                  5
# 1413697                8                    1                  5
# 1413698                8                    1                  5
# 1413699                8                    1                  5
# 1413700                8                    1                  5
#
#          PRODUCT_COMBINATION  CODE_REJECT_REASON  NAME_CONTRACT_STATUS  \
# 0                         15                   7                     0
# 1                          7                   7                     0
# 2                         11                   7                     0
# 3                          9                   7                     0
# 4                         14                   7                     0
# ...                      ...                 ...                   ...
# 1413696                    8                   7                     0
# 1413697                    0                   1                     2
# 1413698                    4                   1                     2
# 1413699                    7                   7                     0
# 1413700                   13                   7                     0
#
#          NAME_INCOME_TYPE  NAME_YIELD_GROUP  CODE_GENDER  NAME_GOODS_CATEGORY
# 0                       5                 3            1                   24
# 1                       3                 3            0                   26
# 2                       3                 4            0                   11
# 3                       3                 4            0                    7
# 4                       5                 4            1                   18
# ...                   ...               ...          ...                  ...
# 1413696                 0                 4            0                   26
# 1413697                 0                 0            0                   26
# 1413698                 0                 3            0                   26
# 1413699                 0                 3            0                   26
# 1413700                 0                 1            0                    5
#
# [956121 rows x 10 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corrMatrix = df_1.corr()
plt.figure(figsize=(10, 6))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %%
import scipy.stats as stats

# Initialize an empty dictionary to store p-values
p_values = {}

# Iterate over each pair of columns
for col1 in df_1.columns:
    for col2 in df_1.columns:
        if col1 != col2:  
            # Calculate correlation coefficient and p-value
            r, p = stats.pearsonr(df_1[col1], df_1[col2])
            # Store p-value in the dictionary
            p_values[(col1, col2)] = p

# Print p-values
print(p_values)
# Out:
# {('OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE'): 0.0, ('OCCUPATION_TYPE', 'ORGANIZATION_TYPE'): 0.0, ('OCCUPATION_TYPE', 'PRODUCT_COMBINATION'): 4.301647196811514e-19, ('OCCUPATION_TYPE', 'CODE_REJECT_REASON'): 4.632131499601164e-07, ('OCCUPATION_TYPE', 'NAME_CONTRACT_STATUS'): 1.3096376470982002e-14, ('OCCUPATION_TYPE', 'NAME_INCOME_TYPE'): 4.646486486749715e-31, ('OCCUPATION_TYPE', 'NAME_YIELD_GROUP'): 1.8547551541097713e-10, ('OCCUPATION_TYPE', 'CODE_GENDER'): 0.0, ('OCCUPATION_TYPE', 'NAME_GOODS_CATEGORY'): 3.913419155087039e-14, ('NAME_EDUCATION_TYPE', 'OCCUPATION_TYPE'): 0.0, ('NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE'): 1.492056773635612e-100, ('NAME_EDUCATION_TYPE', 'PRODUCT_COMBINATION'): 1.253957214982534e-68, ('NAME_EDUCATION_TYPE', 'CODE_REJECT_REASON'): 2.6334515784612758e-17, ('NAME_EDUCATION_TYPE', 'NAME_CONTRACT_STATUS'): 5.644871659617682e-17, ('NAME_EDUCATION_TYPE', 'NAME_INCOME_TYPE'): 0.0, ('NAME_EDUCATION_TYPE', 'NAME_YIELD_GROUP'): 4.913042215406874e-19, ('NAME_EDUCATION_TYPE', 'CODE_GENDER'): 5.7820484293624096e-294, ('NAME_EDUCATION_TYPE', 'NAME_GOODS_CATEGORY'): 1.1721780329146846e-56, ('ORGANIZATION_TYPE', 'OCCUPATION_TYPE'): 0.0, ('ORGANIZATION_TYPE', 'NAME_EDUCATION_TYPE'): 1.492056773635612e-100, ('ORGANIZATION_TYPE', 'PRODUCT_COMBINATION'): 0.0020988048445695897, ('ORGANIZATION_TYPE', 'CODE_REJECT_REASON'): 2.2211752359868546e-10, ('ORGANIZATION_TYPE', 'NAME_CONTRACT_STATUS'): 1.3029267632276044e-14, ('ORGANIZATION_TYPE', 'NAME_INCOME_TYPE'): 2.338938861575926e-86, ('ORGANIZATION_TYPE', 'NAME_YIELD_GROUP'): 0.00323105141470445, ('ORGANIZATION_TYPE', 'CODE_GENDER'): 0.0, ('ORGANIZATION_TYPE', 'NAME_GOODS_CATEGORY'): 0.14342377857969865, ('PRODUCT_COMBINATION', 'OCCUPATION_TYPE'): 4.301647196811514e-19, ('PRODUCT_COMBINATION', 'NAME_EDUCATION_TYPE'): 1.253957214982534e-68, ('PRODUCT_COMBINATION', 'ORGANIZATION_TYPE'): 0.0020988048445695897, ('PRODUCT_COMBINATION', 'CODE_REJECT_REASON'): 0.0, ('PRODUCT_COMBINATION', 'NAME_CONTRACT_STATUS'): 0.0, ('PRODUCT_COMBINATION', 'NAME_INCOME_TYPE'): 5.477621234946902e-224, ('PRODUCT_COMBINATION', 'NAME_YIELD_GROUP'): 0.0, ('PRODUCT_COMBINATION', 'CODE_GENDER'): 4.498697722658662e-62, ('PRODUCT_COMBINATION', 'NAME_GOODS_CATEGORY'): 0.0, ('CODE_REJECT_REASON', 'OCCUPATION_TYPE'): 4.632131499601164e-07, ('CODE_REJECT_REASON', 'NAME_EDUCATION_TYPE'): 2.633451578467527e-17, ('CODE_REJECT_REASON', 'ORGANIZATION_TYPE'): 2.2211752359868546e-10, ('CODE_REJECT_REASON', 'PRODUCT_COMBINATION'): 0.0, ('CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS'): 0.0, ('CODE_REJECT_REASON', 'NAME_INCOME_TYPE'): 0.09169926729521648, ('CODE_REJECT_REASON', 'NAME_YIELD_GROUP'): 0.0, ('CODE_REJECT_REASON', 'CODE_GENDER'): 7.653907289405984e-07, ('CODE_REJECT_REASON', 'NAME_GOODS_CATEGORY'): 0.0, ('NAME_CONTRACT_STATUS', 'OCCUPATION_TYPE'): 1.3096376470982002e-14, ('NAME_CONTRACT_STATUS', 'NAME_EDUCATION_TYPE'): 5.644871659617682e-17, ('NAME_CONTRACT_STATUS', 'ORGANIZATION_TYPE'): 1.3029267632276044e-14, ('NAME_CONTRACT_STATUS', 'PRODUCT_COMBINATION'): 0.0, ('NAME_CONTRACT_STATUS', 'CODE_REJECT_REASON'): 0.0, ('NAME_CONTRACT_STATUS', 'NAME_INCOME_TYPE'): 0.0012632254531854594, ('NAME_CONTRACT_STATUS', 'NAME_YIELD_GROUP'): 0.0, ('NAME_CONTRACT_STATUS', 'CODE_GENDER'): 2.6381115052836637e-19, ('NAME_CONTRACT_STATUS', 'NAME_GOODS_CATEGORY'): 0.0, ('NAME_INCOME_TYPE', 'OCCUPATION_TYPE'): 4.646486486749715e-31, ('NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE'): 0.0, ('NAME_INCOME_TYPE', 'ORGANIZATION_TYPE'): 2.3389388615909802e-86, ('NAME_INCOME_TYPE', 'PRODUCT_COMBINATION'): 5.477621234946902e-224, ('NAME_INCOME_TYPE', 'CODE_REJECT_REASON'): 0.09169926729521648, ('NAME_INCOME_TYPE', 'NAME_CONTRACT_STATUS'): 0.0012632254531854594, ('NAME_INCOME_TYPE', 'NAME_YIELD_GROUP'): 0.9069068922875585, ('NAME_INCOME_TYPE', 'CODE_GENDER'): 5.261900956264298e-41, ('NAME_INCOME_TYPE', 'NAME_GOODS_CATEGORY'): 5.820946126151739e-135, ('NAME_YIELD_GROUP', 'OCCUPATION_TYPE'): 1.8547551541097713e-10, ('NAME_YIELD_GROUP', 'NAME ...

# %%
print("\nNumerical Columns:")
print(numerical_cols)
# Out:
# Numerical Columns:
# Index(['SK_ID_CURR', 'TARGET', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT_x', 'AMT_ANNUITY_x', 'AMT_GOODS_PRICE_x',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        ...
#        'RATE_INTEREST_PRIVILEGED', 'DAYS_DECISION', 'SELLERPLACE_AREA',
#        'CNT_PAYMENT', 'DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE',
#        'DAYS_LAST_DUE_1ST_VERSION', 'DAYS_LAST_DUE', 'DAYS_TERMINATION',
#        'NFLAG_INSURED_ON_APPROVAL'],
#       dtype='object', length=126)

# %%
for i in numerical_cols:
    df[i] = df[i].fillna(df[i].mean())

# %%
# Check for null values in numerical columns
numerical_nulls = df[numerical_cols].isnull().sum().head(50)
print("Numerical Null Values:")
print(numerical_nulls)
# Out:
# Numerical Null Values:
# SK_ID_CURR                      0
# TARGET                          0
# CNT_CHILDREN                    0
# AMT_INCOME_TOTAL                0
# AMT_CREDIT_x                    0
# AMT_ANNUITY_x                   0
# AMT_GOODS_PRICE_x               0
# REGION_POPULATION_RELATIVE      0
# DAYS_BIRTH                      0
# DAYS_EMPLOYED                   0
# DAYS_REGISTRATION               0
# DAYS_ID_PUBLISH                 0
# OWN_CAR_AGE                     0
# FLAG_MOBIL                      0
# FLAG_EMP_PHONE                  0
# FLAG_WORK_PHONE                 0
# FLAG_CONT_MOBILE                0
# FLAG_PHONE                      0
# FLAG_EMAIL                      0
# CNT_FAM_MEMBERS                 0
# REGION_RATING_CLIENT            0
# REGION_RATING_CLIENT_W_CITY     0
# HOUR_APPR_PROCESS_START_x       0
# REG_REGION_NOT_LIVE_REGION      0
# REG_REGION_NOT_WORK_REGION      0
# LIVE_REGION_NOT_WORK_REGION     0
# REG_CITY_NOT_LIVE_CITY          0
# REG_CITY_NOT_WORK_CITY          0
# LIVE_CITY_NOT_WORK_CITY         0
# EXT_SOURCE_1                    0
# EXT_SOURCE_2                    0
# EXT_SOURCE_3                    0
# APARTMENTS_AVG                  0
# BASEMENTAREA_AVG                0
# YEARS_BEGINEXPLUATATION_AVG     0
# YEARS_BUILD_AVG                 0
# COMMONAREA_AVG                  0
# ELEVATORS_AVG                   0
# ENTRANCES_AVG                   0
# FLOORSMAX_AVG                   0
# FLOORSMIN_AVG                   0
# LANDAREA_AVG                    0
# LIVINGAPARTMENTS_AVG            0
# LIVINGAREA_AVG                  0
# NONLIVINGAPARTMENTS_AVG         0
# NONLIVINGAREA_AVG               0
# APARTMENTS_MODE                 0
# BASEMENTAREA_MODE               0
# YEARS_BEGINEXPLUATATION_MODE    0
# YEARS_BUILD_MODE                0
# dtype: int64

# %%
# Calculate correlation coefficients for continuous features(identify strength and direction b/w two con variable)
corr_coeffs = []
for feature in numerical_cols:
    corr, _ = pearsonr(df[feature], df['TARGET'])
    corr_coeffs.append(corr)
# Out:
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\3648278418.py:4: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, _ = pearsonr(df[feature], df['TARGET'])

# %%
hybrid_scores = [0.5 * corr for corr in corr_coeffs]

# %%
# Rank categorical features by mutual information scores
ranked_continuous_features = [feature for _, feature in sorted(zip(corr_coeffs, numerical_cols), reverse=True)]

# %%
# Select top N features
N = 10
selected_features = ranked_continuous_features[:N]

print("Selected Features:", selected_features)
# Out:
# Selected Features: ['TARGET', 'FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY', 'REGION_RATING_CLIENT', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_DECISION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY']

# %%
df1 = df[['TARGET','AMT_INCOME_TOTAL','DAYS_BIRTH', 'FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY', 'REGION_RATING_CLIENT', 'DAYS_ID_PUBLISH', 'REG_CITY_NOT_WORK_CITY', 'FLAG_EMP_PHONE', 'DAYS_REGISTRATION']]

# %%
df1['DAYS_BIRTH'] = df1['DAYS_BIRTH'].abs()  # making absolute values
df1["DAYS_LAST_PHONE_CHANGE"]=df1["DAYS_LAST_PHONE_CHANGE"].abs()
df1['DAYS_ID_PUBLISH'] = df1['DAYS_ID_PUBLISH'].abs()  # making absolute values
df1["DAYS_REGISTRATION"]=df1["DAYS_REGISTRATION"].abs()
# Out:
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\3438837914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['DAYS_BIRTH'] = df1['DAYS_BIRTH'].abs()  # making absolute values
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\3438837914.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["DAYS_LAST_PHONE_CHANGE"]=df1["DAYS_LAST_PHONE_CHANGE"].abs()
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\3438837914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['DAYS_ID_PUBLISH'] = df1['DAYS_ID_PUBLISH'].abs()  # making absolute values
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\3438837914.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["DAYS_REGISTRATION"]=df1["DAYS_REGISTRATION"].abs()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corrMatrix = df1.corr()
plt.figure(figsize=(10, 6))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
import scipy.stats as stats

# Initialize an empty dictionary to store p-values
p_values = {}

# Iterate over each pair of columns
for col1 in df1.columns:
    for col2 in df1.columns:
        if col1 != col2:  # Avoid calculating correlation for the same column
            # Calculate correlation coefficient and p-value
            r, p = stats.pearsonr(df1[col1], df1[col2])
            # Store p-value in the dictionary
            p_values[(col1, col2)] = p

# Print p-values
print(p_values)
# Out:
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\2652083736.py:24: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(df1[col1], df1[col2])
# {('TARGET', 'AMT_INCOME_TOTAL'): 3.7747905348094267e-05, ('TARGET', 'DAYS_BIRTH'): 0.0, ('TARGET', 'FLAG_MOBIL'): nan, ('TARGET', 'DAYS_LAST_PHONE_CHANGE'): 0.0, ('TARGET', 'REGION_RATING_CLIENT_W_CITY'): 0.0, ('TARGET', 'REGION_RATING_CLIENT'): 0.0, ('TARGET', 'DAYS_ID_PUBLISH'): 4.4946212418376884e-306, ('TARGET', 'REG_CITY_NOT_WORK_CITY'): 0.0, ('TARGET', 'FLAG_EMP_PHONE'): 0.3627144180408357, ('TARGET', 'DAYS_REGISTRATION'): 1.3726463758669772e-291, ('AMT_INCOME_TOTAL', 'TARGET'): 3.7747905348094267e-05, ('AMT_INCOME_TOTAL', 'DAYS_BIRTH'): 7.749939358736573e-187, ('AMT_INCOME_TOTAL', 'FLAG_MOBIL'): nan, ('AMT_INCOME_TOTAL', 'DAYS_LAST_PHONE_CHANGE'): 8.694519853796222e-105, ('AMT_INCOME_TOTAL', 'REGION_RATING_CLIENT_W_CITY'): 0.0, ('AMT_INCOME_TOTAL', 'REGION_RATING_CLIENT'): 0.0, ('AMT_INCOME_TOTAL', 'DAYS_ID_PUBLISH'): 3.740959447130514e-15, ('AMT_INCOME_TOTAL', 'REG_CITY_NOT_WORK_CITY'): 8.024484094193952e-20, ('AMT_INCOME_TOTAL', 'FLAG_EMP_PHONE'): 0.6036704167148245, ('AMT_INCOME_TOTAL', 'DAYS_REGISTRATION'): 5.013861635176271e-25, ('DAYS_BIRTH', 'TARGET'): 0.0, ('DAYS_BIRTH', 'AMT_INCOME_TOTAL'): 7.749939358736573e-187, ('DAYS_BIRTH', 'FLAG_MOBIL'): nan, ('DAYS_BIRTH', 'DAYS_LAST_PHONE_CHANGE'): 0.0, ('DAYS_BIRTH', 'REGION_RATING_CLIENT_W_CITY'): 0.0, ('DAYS_BIRTH', 'REGION_RATING_CLIENT'): 0.0, ('DAYS_BIRTH', 'DAYS_ID_PUBLISH'): 0.0, ('DAYS_BIRTH', 'REG_CITY_NOT_WORK_CITY'): 0.0, ('DAYS_BIRTH', 'FLAG_EMP_PHONE'): 0.00114819729398858, ('DAYS_BIRTH', 'DAYS_REGISTRATION'): 0.0, ('FLAG_MOBIL', 'TARGET'): nan, ('FLAG_MOBIL', 'AMT_INCOME_TOTAL'): nan, ('FLAG_MOBIL', 'DAYS_BIRTH'): nan, ('FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE'): nan, ('FLAG_MOBIL', 'REGION_RATING_CLIENT_W_CITY'): nan, ('FLAG_MOBIL', 'REGION_RATING_CLIENT'): nan, ('FLAG_MOBIL', 'DAYS_ID_PUBLISH'): nan, ('FLAG_MOBIL', 'REG_CITY_NOT_WORK_CITY'): nan, ('FLAG_MOBIL', 'FLAG_EMP_PHONE'): nan, ('FLAG_MOBIL', 'DAYS_REGISTRATION'): nan, ('DAYS_LAST_PHONE_CHANGE', 'TARGET'): 0.0, ('DAYS_LAST_PHONE_CHANGE', 'AMT_INCOME_TOTAL'): 8.694519853796222e-105, ('DAYS_LAST_PHONE_CHANGE', 'DAYS_BIRTH'): 0.0, ('DAYS_LAST_PHONE_CHANGE', 'FLAG_MOBIL'): nan, ('DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY'): 1.2856719852489911e-235, ('DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT'): 1.418381737609054e-241, ('DAYS_LAST_PHONE_CHANGE', 'DAYS_ID_PUBLISH'): 0.0, ('DAYS_LAST_PHONE_CHANGE', 'REG_CITY_NOT_WORK_CITY'): 0.0, ('DAYS_LAST_PHONE_CHANGE', 'FLAG_EMP_PHONE'): 0.10047423703781633, ('DAYS_LAST_PHONE_CHANGE', 'DAYS_REGISTRATION'): 0.0, ('REGION_RATING_CLIENT_W_CITY', 'TARGET'): 0.0, ('REGION_RATING_CLIENT_W_CITY', 'AMT_INCOME_TOTAL'): 0.0, ('REGION_RATING_CLIENT_W_CITY', 'DAYS_BIRTH'): 0.0, ('REGION_RATING_CLIENT_W_CITY', 'FLAG_MOBIL'): nan, ('REGION_RATING_CLIENT_W_CITY', 'DAYS_LAST_PHONE_CHANGE'): 1.2856719852489911e-235, ('REGION_RATING_CLIENT_W_CITY', 'REGION_RATING_CLIENT'): 0.0, ('REGION_RATING_CLIENT_W_CITY', 'DAYS_ID_PUBLISH'): 3.017616126782005e-08, ('REGION_RATING_CLIENT_W_CITY', 'REG_CITY_NOT_WORK_CITY'): 1.733121336821013e-215, ('REGION_RATING_CLIENT_W_CITY', 'FLAG_EMP_PHONE'): 0.6063128147243703, ('REGION_RATING_CLIENT_W_CITY', 'DAYS_REGISTRATION'): 0.0, ('REGION_RATING_CLIENT', 'TARGET'): 0.0, ('REGION_RATING_CLIENT', 'AMT_INCOME_TOTAL'): 0.0, ('REGION_RATING_CLIENT', 'DAYS_BIRTH'): 0.0, ('REGION_RATING_CLIENT', 'FLAG_MOBIL'): nan, ('REGION_RATING_CLIENT', 'DAYS_LAST_PHONE_CHANGE'): 1.418381737609054e-241, ('REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY'): 0.0, ('REGION_RATING_CLIENT', 'DAYS_ID_PUBLISH'): 3.3483950124874013e-14, ('REGION_RATING_CLIENT', 'REG_CITY_NOT_WORK_CITY'): 9.074875971176698e-13, ('REGION_RATING_CLIENT', 'FLAG_EMP_PHONE'): 0.402875286566082, ('REGION_RATING_CLIENT', 'DAYS_REGISTRATION'): 0.0, ('DAYS_ID_PUBLISH', 'TARGET'): 4.4946212418376884e-306, ('DAYS_ID_PUBLISH', 'AMT_INCOME_TOTAL'): 3.740959447130514e-15, ('DAYS_ID_PUBLISH', 'DAYS_BIRTH'): 0.0, ('DAYS_ID_PUBLISH', 'FLAG_MOBIL'): nan, ('DAYS_ID_PUBLISH', 'DAYS_LAST_PHONE_CHANGE'): ...

# %%
df_modified = pd.concat([df_1,df1],axis=1)
df_modified.head(5)
# Out:
#    OCCUPATION_TYPE  NAME_EDUCATION_TYPE  ORGANIZATION_TYPE  \
# 0                8                    4                  5
# 1                3                    1                 39
# 2                3                    1                 39
# 3                3                    1                 39
# 4                8                    4                 11
#
#    PRODUCT_COMBINATION  CODE_REJECT_REASON  NAME_CONTRACT_STATUS  \
# 0                   15                   7                     0
# 1                    7                   7                     0
# 2                   11                   7                     0
# 3                    9                   7                     0
# 4                   14                   7                     0
#
#    NAME_INCOME_TYPE  NAME_YIELD_GROUP  CODE_GENDER  NAME_GOODS_CATEGORY  ...  \
# 0                 5                 3            1                   24  ...
# 1                 3                 3            0                   26  ...
# 2                 3                 4            0                   11  ...
# 3                 3                 4            0                    7  ...
# 4                 5                 4            1                   18  ...
#
#    AMT_INCOME_TOTAL  DAYS_BIRTH  FLAG_MOBIL  DAYS_LAST_PHONE_CHANGE  \
# 0          202500.0        9461           1                  1134.0
# 1          270000.0       16765           1                   828.0
# 2          270000.0       16765           1                   828.0
# 3          270000.0       16765           1                   828.0
# 4           67500.0       19046           1                   815.0
#
#    REGION_RATING_CLIENT_W_CITY  REGION_RATING_CLIENT  DAYS_ID_PUBLISH  \
# 0                            2                     2             2120
# 1                            1                     1              291
# 2                            1                     1              291
# 3                            1                     1              291
# 4                            2                     2             2531
#
#    REG_CITY_NOT_WORK_CITY  FLAG_EMP_PHONE  DAYS_REGISTRATION
# 0                       0               1             3648.0
# 1                       0               1             1186.0
# 2                       0               1             1186.0
# 3                       0               1             1186.0
# 4                       0               1             4260.0
#
# [5 rows x 21 columns]

# %%
# detecting the skewed columns using plot

def skewplot(df, column):
    plt.figure(figsize=(10, 4))

    # Distplot
    plt.subplot(1, 3, 1)
    sns.distplot(df[column], kde=True)
    plt.title("Distplot for " + column)

    # Boxplot
    plt.subplot(1, 3, 2)
    sns.boxplot(df[column])
    plt.title("Box plot for " + column)

    plt.tight_layout()
    plt.show()

# %%
df_modified.columns
# Out:
# Index(['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE',
#        'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS',
#        'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER',
#        'NAME_GOODS_CATEGORY', 'TARGET', 'AMT_INCOME_TOTAL', 'DAYS_BIRTH',
#        'FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY',
#        'REGION_RATING_CLIENT', 'DAYS_ID_PUBLISH', 'REG_CITY_NOT_WORK_CITY',
#        'FLAG_EMP_PHONE', 'DAYS_REGISTRATION'],
#       dtype='object')

# %%
skewed_columns= ['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE',
       'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS',
       'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER',
       'NAME_GOODS_CATEGORY', 'TARGET', 'AMT_INCOME_TOTAL', 'DAYS_BIRTH',
       'FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY',
       'REGION_RATING_CLIENT', 'DAYS_ID_PUBLISH', 'REG_CITY_NOT_WORK_CITY',
       'FLAG_EMP_PHONE', 'DAYS_REGISTRATION']
 

for column in skewed_columns:
    skewplot(df_modified, column)
# Out:
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\anaconda3\jupyter\Lib\site-packages\seaborn\distributions.py:2496: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)

# %%
# Apply square root transformation to the specified columns
df_modified['NAME_EDUCATION_TYPE_log'] = np.log(df_modified['NAME_EDUCATION_TYPE'])
df_modified["PRODUCT_COMBINATION_log"] = np.log(df_modified["PRODUCT_COMBINATION"])
df_modified["CODE_REJECT_REASON_log"] = np.log(df_modified["CODE_REJECT_REASON"])
df_modified["NAME_INCOME_TYPE_log"] = np.log(df_modified["NAME_INCOME_TYPE"])
df_modified["NAME_GOODS_CATEGORY_log"] = np.log(df_modified["NAME_GOODS_CATEGORY"])
df_modified["AMT_INCOME_TOTAL_log"] = np.log(df_modified["AMT_INCOME_TOTAL"])
df_modified["DAYS_LAST_PHONE_CHANGE_log"] = np.log(df_modified["DAYS_LAST_PHONE_CHANGE"])
df_modified["DAYS_ID_PUBLISH_log"] = np.log(df_modified["DAYS_ID_PUBLISH"])
df_modified["DAYS_REGISTRATION_log"] = np.log(df_modified["DAYS_REGISTRATION"])
# Out:
# C:\Users\bswar\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\bswar\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\bswar\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\bswar\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\bswar\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\bswar\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\bswar\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\bswar\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_modified.columns
# Out:
# Index(['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE',
#        'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS',
#        'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER',
#        'NAME_GOODS_CATEGORY', 'TARGET', 'AMT_INCOME_TOTAL', 'DAYS_BIRTH',
#        'FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY',
#        'REGION_RATING_CLIENT', 'DAYS_ID_PUBLISH', 'REG_CITY_NOT_WORK_CITY',
#        'FLAG_EMP_PHONE', 'DAYS_REGISTRATION', 'NAME_EDUCATION_TYPE_log',
#        'PRODUCT_COMBINATION_log', 'CODE_REJECT_REASON_log',
#        'NAME_INCOME_TYPE_log', 'NAME_GOODS_CATEGORY_log',
#        'AMT_INCOME_TOTAL_log', 'DAYS_LAST_PHONE_CHANGE_log',
#        'DAYS_ID_PUBLISH_log', 'DAYS_REGISTRATION_log'],
#       dtype='object')

# %%
def outlier(df,column):
  q1= df[column].quantile(0.25)
  q3= df[column].quantile(0.75)
  iqr= q3-q1

  upper_threshold= q3 + (1.5*iqr)
  lower_threshold= q1 - (1.5*iqr)

  df[column]= df[column].clip(lower_threshold, upper_threshold)

# %%
outlier_columns= ['CODE_REJECT_REASON','NAME_GOODS_CATEGORY','NAME_INCOME_TYPE','AMT_INCOME_TOTAL','DAYS_LAST_PHONE_CHANGE','DAYS_ID_PUBLISH','DAYS_REGISTRATION']

for i in outlier_columns:
  outlier(df_modified,i)

# %%
for i in outlier_columns:
  skewplot(df_modified,i)
# Out:
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\anaconda3\jupyter\Lib\site-packages\seaborn\distributions.py:2496: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)
# C:\Users\bswar\AppData\Local\Temp\ipykernel_3944\1630934669.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column], kde=True)

# %%
df_modified[['DAYS_REGISTRATION','TARGET']]
# Out:
#          DAYS_REGISTRATION  TARGET
# 0                   3648.0       1
# 1                   1186.0       0
# 2                   1186.0       0
# 3                   1186.0       0
# 4                   4260.0       0
# ...                    ...     ...
# 1413696             5128.0       0
# 1413697             5128.0       0
# 1413698             5128.0       0
# 1413699             5128.0       0
# 1413700             5128.0       0
#
# [956121 rows x 2 columns]

# %%
df_modified.head(5)
# Out:
#    OCCUPATION_TYPE  NAME_EDUCATION_TYPE  ORGANIZATION_TYPE  \
# 0                8                    4                  5
# 1                3                    1                 39
# 2                3                    1                 39
# 3                3                    1                 39
# 4                8                    4                 11
#
#    PRODUCT_COMBINATION  CODE_REJECT_REASON  NAME_CONTRACT_STATUS  \
# 0                   15                   7                     0
# 1                    7                   7                     0
# 2                   11                   7                     0
# 3                    9                   7                     0
# 4                   14                   7                     0
#
#    NAME_INCOME_TYPE  NAME_YIELD_GROUP  CODE_GENDER  NAME_GOODS_CATEGORY  ...  \
# 0                 5                 3            1                   24  ...
# 1                 3                 3            0                   26  ...
# 2                 3                 4            0                   11  ...
# 3                 3                 4            0                    7  ...
# 4                 5                 4            1                   18  ...
#
#    DAYS_REGISTRATION  NAME_EDUCATION_TYPE_log  PRODUCT_COMBINATION_log  \
# 0             3648.0                 1.386294                 2.708050
# 1             1186.0                 0.000000                 1.945910
# 2             1186.0                 0.000000                 2.397895
# 3             1186.0                 0.000000                 2.197225
# 4             4260.0                 1.386294                 2.639057
#
#    CODE_REJECT_REASON_log  NAME_INCOME_TYPE_log  NAME_GOODS_CATEGORY_log  \
# 0                 1.94591              1.609438                 3.178054
# 1                 1.94591              1.098612                 3.258097
# 2                 1.94591              1.098612                 2.397895
# 3                 1.94591              1.098612                 1.945910
# 4                 1.94591              1.609438                 2.890372
#
#    AMT_INCOME_TOTAL_log  DAYS_LAST_PHONE_CHANGE_log  DAYS_ID_PUBLISH_log  \
# 0             12.218495                    7.033506             7.659171
# 1             12.506177                    6.719013             5.673323
# 2             12.506177                    6.719013             5.673323
# 3             12.506177                    6.719013             5.673323
# 4             11.119883                    6.703188             7.836370
#
#    DAYS_REGISTRATION_log
# 0               8.201934
# 1               7.078342
# 2               7.078342
# 3               7.078342
# 4               8.357024
#
# [5 rows x 30 columns]

# %%
df_modified_1 = df_modified.copy()

# %%
df_modified_1.columns
# Out:
# Index(['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE',
#        'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS',
#        'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER',
#        'NAME_GOODS_CATEGORY', 'TARGET', 'AMT_INCOME_TOTAL', 'DAYS_BIRTH',
#        'FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY',
#        'REGION_RATING_CLIENT', 'DAYS_ID_PUBLISH', 'REG_CITY_NOT_WORK_CITY',
#        'FLAG_EMP_PHONE', 'DAYS_REGISTRATION', 'NAME_EDUCATION_TYPE_log',
#        'PRODUCT_COMBINATION_log', 'CODE_REJECT_REASON_log',
#        'NAME_INCOME_TYPE_log', 'NAME_GOODS_CATEGORY_log',
#        'AMT_INCOME_TOTAL_log', 'DAYS_LAST_PHONE_CHANGE_log',
#        'DAYS_ID_PUBLISH_log', 'DAYS_REGISTRATION_log'],
#       dtype='object')

# %%
df_modified_1.to_csv("df_new.csv")

# %%
df_2 = pd.read_csv("df_new.csv")
df_2.head(5)
# Out:
#    Unnamed: 0  OCCUPATION_TYPE  NAME_EDUCATION_TYPE  ORGANIZATION_TYPE  \
# 0           0                8                    4                  5
# 1           1                3                    1                 39
# 2           2                3                    1                 39
# 3           3                3                    1                 39
# 4           4                8                    4                 11
#
#    PRODUCT_COMBINATION  CODE_REJECT_REASON  NAME_CONTRACT_STATUS  \
# 0                   15                   7                     0
# 1                    7                   7                     0
# 2                   11                   7                     0
# 3                    9                   7                     0
# 4                   14                   7                     0
#
#    NAME_INCOME_TYPE  NAME_YIELD_GROUP  CODE_GENDER  ...  DAYS_REGISTRATION  \
# 0                 5                 3            1  ...             3648.0
# 1                 3                 3            0  ...             1186.0
# 2                 3                 4            0  ...             1186.0
# 3                 3                 4            0  ...             1186.0
# 4                 5                 4            1  ...             4260.0
#
#    NAME_EDUCATION_TYPE_log  PRODUCT_COMBINATION_log  CODE_REJECT_REASON_log  \
# 0                 1.386294                 2.708050                 1.94591
# 1                 0.000000                 1.945910                 1.94591
# 2                 0.000000                 2.397895                 1.94591
# 3                 0.000000                 2.197225                 1.94591
# 4                 1.386294                 2.639057                 1.94591
#
#    NAME_INCOME_TYPE_log  NAME_GOODS_CATEGORY_log  AMT_INCOME_TOTAL_log  \
# 0              1.609438                 3.178054             12.218495
# 1              1.098612                 3.258097             12.506177
# 2              1.098612                 2.397895             12.506177
# 3              1.098612                 1.945910             12.506177
# 4              1.609438                 2.890372             11.119883
#
#    DAYS_LAST_PHONE_CHANGE_log  DAYS_ID_PUBLISH_log  DAYS_REGISTRATION_log
# 0                    7.033506             7.659171               8.201934
# 1                    6.719013             5.673323               7.078342
# 2                    6.719013             5.673323               7.078342
# 3                    6.719013             5.673323               7.078342
# 4                    6.703188             7.836370               8.357024
#
# [5 rows x 31 columns]

# %%
# Feature Engineering
# 1. Extract age from DAYS_BIRTH
df_2['AGE'] = df_2['DAYS_BIRTH'] / -365

# %%
df_2['AGE'] = df_2['AGE'].abs()

# %%
df_2['AGE'].isnull().sum()
# Out:
# 0

# %%
df_2['INCOME_PA'] = df_2['AMT_INCOME_TOTAL']*12

# %%
# Group by income_type and income_percentile_bin
grouped_df = df_2.groupby(['NAME_INCOME_TYPE', 'INCOME_PA']).size().reset_index(name='count')

# Print the grouped data
print(grouped_df)
# Out:
#       NAME_INCOME_TYPE  INCOME_PA  count
# 0                    0   318600.0      2
# 1                    0   324000.0      4
# 2                    0   351000.0      1
# 3                    0   378000.0     27
# 4                    0   405000.0      1
# ...                ...        ...    ...
# 1758                 5  4590000.0   1730
# 1759                 5  4637682.0     21
# 1760                 5  4644000.0    195
# 1761                 5  4698000.0    143
# 1762                 5  4725000.0  11172
#
# [1763 rows x 3 columns]

# %%
grouped_df.max()
# Out:
# NAME_INCOME_TYPE          5.0
# INCOME_PA           4725000.0
# count                 75818.0
# dtype: float64

# %%
df_2['INCOME_PA'].max()
# Out:
# 4725000.0

# %%
df_2['CLIENT_RATING'] = pd.cut(df_2['REGION_RATING_CLIENT_W_CITY'], bins=[0,1,2,3], labels=['Low', 'Medium', 'High'])

# %%
df_2['CLIENT_RATING_W_CITY'] =  df_2['CLIENT_RATING'].map({'Low': 1, 'Medium': 2, 'High': 3})

# %%
df_2['DAYS_LAST_PHONE_CHANGE_log'].unique()
# Out:
# array([7.03350648, 6.71901315, 6.70318811, ..., 8.33639048, 8.17301131,
#        8.17131687])

# %%
df_2['CLIENT_RATING_W_CITY'].unique()
# Out:
# [2, 1, 3]
# Categories (3, int64): [1 < 2 < 3]

# %%
df_2['CLIENT_RATING_W_CITY'] = df_2['CLIENT_RATING_W_CITY'].astype(int)
df_2['AGE'] = df_2['AGE'].astype(int)

# %%
df_2.columns
# Out:
# Index(['Unnamed: 0', 'OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE',
#        'ORGANIZATION_TYPE', 'PRODUCT_COMBINATION', 'CODE_REJECT_REASON',
#        'NAME_CONTRACT_STATUS', 'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP',
#        'CODE_GENDER', 'NAME_GOODS_CATEGORY', 'TARGET', 'AMT_INCOME_TOTAL',
#        'DAYS_BIRTH', 'FLAG_MOBIL', 'DAYS_LAST_PHONE_CHANGE',
#        'REGION_RATING_CLIENT_W_CITY', 'REGION_RATING_CLIENT',
#        'DAYS_ID_PUBLISH', 'REG_CITY_NOT_WORK_CITY', 'FLAG_EMP_PHONE',
#        'DAYS_REGISTRATION', 'NAME_EDUCATION_TYPE_log',
#        'PRODUCT_COMBINATION_log', 'CODE_REJECT_REASON_log',
#        'NAME_INCOME_TYPE_log', 'NAME_GOODS_CATEGORY_log',
#        'AMT_INCOME_TOTAL_log', 'DAYS_LAST_PHONE_CHANGE_log',
#        'DAYS_ID_PUBLISH_log', 'DAYS_REGISTRATION_log', 'AGE', 'INCOME_PA',
#        'CLIENT_RATING', 'CLIENT_RATING_W_CITY'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ddff = df_2[['OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'ORGANIZATION_TYPE',
       'PRODUCT_COMBINATION', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS',
       'NAME_INCOME_TYPE', 'NAME_YIELD_GROUP', 'CODE_GENDER',
       'NAME_GOODS_CATEGORY', 'TARGET', 'AGE', 'INCOME_PA',
       'CLIENT_RATING_W_CITY','FLAG_MOBIL',
       'DAYS_LAST_PHONE_CHANGE', 'REGION_RATING_CLIENT_W_CITY',
       'REGION_RATING_CLIENT', 'DAYS_ID_PUBLISH', 'REG_CITY_NOT_WORK_CITY',
       'FLAG_EMP_PHONE', 'DAYS_REGISTRATION', 'NAME_EDUCATION_TYPE_log',
       'PRODUCT_COMBINATION_log', 'CODE_REJECT_REASON_log',
       'NAME_INCOME_TYPE_log', 'NAME_GOODS_CATEGORY_log',
       'DAYS_LAST_PHONE_CHANGE_log', 'DAYS_ID_PUBLISH_log',
       'DAYS_REGISTRATION_log']]

# Calculate the correlation matrix
corr = ddff.corr()

# Plot the heatmap
plt.figure(figsize=(20, 10))
sns.heatmap(corr, annot=True, fmt=".2f",cmap="YlGnBu")
plt.show()

# %%
#Split train and test data
final_data = df_2[['TARGET','OCCUPATION_TYPE','NAME_EDUCATION_TYPE',
                   'NAME_INCOME_TYPE','INCOME_PA','CODE_REJECT_REASON',
                   'NAME_CONTRACT_STATUS','NAME_YIELD_GROUP',
                    'CODE_GENDER','AGE','CLIENT_RATING_W_CITY',
                    'DAYS_LAST_PHONE_CHANGE_log', 'DAYS_ID_PUBLISH_log',
                    'DAYS_REGISTRATION_log']]

# %%
final_data.head(5)
# Out:
#    TARGET  OCCUPATION_TYPE  NAME_EDUCATION_TYPE  NAME_INCOME_TYPE  INCOME_PA  \
# 0       1                8                    4                 5  2430000.0
# 1       0                3                    1                 3  3240000.0
# 2       0                3                    1                 3  3240000.0
# 3       0                3                    1                 3  3240000.0
# 4       0                8                    4                 5   810000.0
#
#    CODE_REJECT_REASON  NAME_CONTRACT_STATUS  NAME_YIELD_GROUP  CODE_GENDER  \
# 0                   7                     0                 3            1
# 1                   7                     0                 3            0
# 2                   7                     0                 4            0
# 3                   7                     0                 4            0
# 4                   7                     0                 4            1
#
#    AGE  CLIENT_RATING_W_CITY  DAYS_LAST_PHONE_CHANGE_log  DAYS_ID_PUBLISH_log  \
# 0   25                     2                    7.033506             7.659171
# 1   45                     1                    6.719013             5.673323
# 2   45                     1                    6.719013             5.673323
# 3   45                     1                    6.719013             5.673323
# 4   52                     2                    6.703188             7.836370
#
#    DAYS_REGISTRATION_log
# 0               8.201934
# 1               7.078342
# 2               7.078342
# 3               7.078342
# 4               8.357024

# %%
final_data['TARGET'].value_counts()
# Out:
# TARGET
# 0    865635
# 1     90486
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split


from imblearn.over_sampling import RandomOverSampler

ro = RandomOverSampler(random_state= 46)

features = final_data.drop('TARGET',axis=1)
target = final_data['TARGET']

re_data, re_tar = ro.fit_resample(features, target)
re_data['TARGET'] = re_tar 

val = re_data.drop('TARGET', axis=1)
tar = re_data['TARGET']

X_train, X_test, y_train, y_test  = train_test_split(val, tar, test_size= 0.2, random_state=46)

X_train = X_train.clip(lower=-1e10, upper=1e10)
X_test = X_test.clip(lower=-1e10, upper=1e10)


print("Training data shapes:")
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")

print("Testing data shapes:")
print(f"X_test: {X_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# Training data shapes:
# X_train: (1385016, 13)
# y_train: (1385016,)
# Testing data shapes:
# X_test: (346254, 13)
# y_test: (346254,)

# %%
re_data['TARGET'].value_counts()
# Out:
# TARGET
# 1    865635
# 0    865635
# Name: count, dtype: int64

# %%
re_data.shape
# Out:
# (1731270, 14)

# %%
#KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

scaler0 = StandardScaler()
X1_train_scaled = scaler0.fit_transform(X_train)
X1_test_scaled = scaler0.transform(X_test)
knn = KNeighborsClassifier(n_neighbors=9)

# Fit the classifier
knn.fit(X1_train_scaled, y_train)

# Predict the labels
y_pred = knn.predict(X1_test_scaled)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
cm = confusion_matrix(y_test, y_pred)
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.8622398586009115
# Confusion Matrix:
# [[130294  42934]
#  [  4766 168260]]

# %%
# Evalution Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))
false, true, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false, true)
plt.plot(false, true, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
# [[130294  42934]
#  [  4766 168260]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.75      0.85    173228
#            1       0.80      0.97      0.88    173026
#
#     accuracy                           0.86    346254
#    macro avg       0.88      0.86      0.86    346254
# weighted avg       0.88      0.86      0.86    346254

# %%
#DecisionTree Classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler


scaler1 = StandardScaler()
X1_train_scaled = scaler1.fit_transform(X_train)
X1_test_scaled = scaler1.transform(X_test)

Decison_tree = DecisionTreeClassifier(
    criterion='gini',
    max_depth=30,
    min_samples_split=6,
    min_samples_leaf=6
)

# Fit the classifier
Decison_tree.fit(X1_train_scaled, y_train)

# Predict the labels
y_pred = Decison_tree.predict(X1_test_scaled)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
cm = confusion_matrix(y_test, y_pred)
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.8568536392359366
# Confusion Matrix:
# [[136792  36436]
#  [ 13129 159897]]

# %%
# Evalution Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))
false, true, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false, true)
plt.plot(false, true, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')   #  DECISON TREE
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
# [[136792  36436]
#  [ 13129 159897]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.85    173228
#            1       0.81      0.92      0.87    173026
#
#     accuracy                           0.86    346254
#    macro avg       0.86      0.86      0.86    346254
# weighted avg       0.86      0.86      0.86    346254

# %%
#RandomForest Classifier
from sklearn.ensemble import RandomForestClassifier    # random forest
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

scaler2 = StandardScaler()
X1_train_scaled = scaler2.fit_transform(X_train)
X1_test_scaled = scaler2.transform(X_test)

random_forest = RandomForestClassifier(
    n_estimators=350,
    max_depth=20,
    min_samples_split=16,
    min_samples_leaf=9,
    criterion='gini',
    max_features='sqrt'
)

# Fit
random_forest.fit(X1_train_scaled, y_train)

# Predict
y_pred_rf = random_forest.predict(X1_test_scaled)

# Evaluate the classifier
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"Accuracy: {accuracy_rf}")
cm_rf = confusion_matrix(y_test, y_pred_rf)
print(f"Confusion Matrix:\n{cm_rf}")
# Out:
# Accuracy: 0.7773339802572677
# Confusion Matrix:
# [[127803  45425]
#  [ 31674 141352]]

# %%
# Evalution Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))
false, true, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false, true)
plt.plot(false, true, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
# [[136792  36436]
#  [ 13129 159897]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.85    173228
#            1       0.81      0.92      0.87    173026
#
#     accuracy                           0.86    346254
#    macro avg       0.86      0.86      0.86    346254
# weighted avg       0.86      0.86      0.86    346254

# %%
#XGB Classifier
from xgboost import XGBClassifier   # xgb
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

scaler3 = StandardScaler()
X1_train_scaled = scaler3.fit_transform(X_train)
X1_test_scaled = scaler3.transform(X_test)

xgb = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss',
                    n_estimators=750,
                    max_depth=9,
                    learning_rate=0.5,
                    subsample=0.9,
                    colsample_bytree=0.9)

# Fit
xgb.fit(X1_train_scaled, y_train)

# Predict
y_pred = xgb.predict(X1_test_scaled)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
cm = confusion_matrix(y_test, y_pred)
print(f"Confusion Matrix:\n{cm}")
# Out:
# C:\Users\bswar\anaconda3\jupyter\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:15:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Accuracy: 0.9838240135854026
# Confusion Matrix:
# [[168694   4534]
#  [  1067 171959]]

# %%
# Evalution Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))

false, true, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false, true)
plt.plot(false, true, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
# [[168694   4534]
#  [  1067 171959]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98    173228
#            1       0.97      0.99      0.98    173026
#
#     accuracy                           0.98    346254
#    macro avg       0.98      0.98      0.98    346254
# weighted avg       0.98      0.98      0.98    346254

# %%
final_data['TARGET'].value_counts()
# Out:
# TARGET
# 0    865635
# 1     90486
# Name: count, dtype: int64

# %%
final_data.columns
# Out:
# Index(['TARGET', 'OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_INCOME_TYPE',
#        'INCOME_PA', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS',
#        'NAME_YIELD_GROUP', 'CODE_GENDER', 'AGE', 'CLIENT_RATING_W_CITY',
#        'DAYS_LAST_PHONE_CHANGE_log', 'DAYS_ID_PUBLISH_log',
#        'DAYS_REGISTRATION_log'],
#       dtype='object')

# %%
sample = np.array([[8,4,5,2430000,7,0,3,1,25,2,np.log(1134.0),np.log(2120),np.log(3648.0)]])
pred = xgb.predict(sample)
if pred==1:
    print('The status is: Wont Repay')
else:
    print('The status is: Repay')
# Out:
# The status is: Wont Repay

# %%
pred
# Out:
# array([1])

# %%
# Saving the model
import pickle
with open('knnmodel_1.pkl', 'wb') as file:
    pickle.dump(knn, file)


with open('dtmodel_1.pkl', 'wb') as file:
    pickle.dump(Decison_tree, file)

with open('rfmodel_1.pkl', 'wb') as file:
    pickle.dump(random_forest, file)

with open('xgbmodel_1.pkl', 'wb') as file:
    pickle.dump(xgb, file)

# %%
import pickle
with open('xgbmodel_1.pkl', 'wb') as file:
    pickle.dump(xgb, file)

# %%
# %run -i bank.py
# Out:
# 2024-11-28 10:18:10.532 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.063 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.063 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.705
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run bank.py [ARGUMENTS]
# 2024-11-28 10:18:19.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.745 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-28 10:18:19.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !streamlit run bank.py
